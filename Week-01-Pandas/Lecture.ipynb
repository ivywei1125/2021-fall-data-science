# %% [markdown]
# # How to handle data in python using Pandas.
# Pandas is like Excel, but does not suck.  Anything you need to do with data, you can do with pandas.  Im going to focus on the 20% of the things that do 80% of the work.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Before we go into coding, lets understand data files first...
# * Who can tell me what a '.csv' file is?

# %%
! open .

# %% [markdown]
# # Lets look at what type of data can live in a '.csv' file
# * Continuous and Categorical

# %%
pd.read_csv??

# %% [markdown]
# # Importing data
# * If data is seperated by `;`, change to `sep=';'`
# * Shift+Tab is your best friend

# %%
# read in the csv file and store it as a variable named 'df'
df = pd.read_csv('data/listings.csv', sep=',')

# display just the first 5 rows
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340

# %% [markdown]
# # Let's find out how to see the 'shape' of our data...

# %%
df.shape
# Out:
# (46527, 16)

# %% [markdown]
# # Basic Syntax
# * Select one column
# * Select multiple columns
#    * Must use a list

# %%
# SELECT ONE COLUMN
df['id']
# Out:
# 0            2595
# 1            3831
# 2            5121
# 3            5136
# 4            5178
#            ...
# 46522    44807522
# 46523    44807786
# 46524    44811717
# 46525    44814944
# 46526    44818009
# Name: id, Length: 46527, dtype: int64

# %%
# SELECT MULTIPLE COLUMNS
cols_to_select = ['id', 'name']
df[ cols_to_select ]
# df[['id', 'name']]
# Out:
#              id                                               name
# 0          2595                              Skylit Midtown Castle
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2          5121                                    BlissArtsSpace!
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden
# 4          5178                   Large Furnished Room Near B'way
# ...         ...                                                ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan
# 46524  44811717  Comfortable safe environment 24hr security camera
# 46525  44814944                 Upper West Side studio 86th Street
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN
#
# [46527 rows x 2 columns]

# %% [markdown]
# ### Selecting rows.

# %%
# Select in index of rows 0 through 5
df.iloc[0:5]
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340

# %%
rows = [0,10,100]
df.iloc[rows]
# Out:
#         id                           name  host_id host_name  \
# 0     2595          Skylit Midtown Castle     2845  Jennifer
# 10    6090  West Village Nest - Superhost    11975     Alina
# 100  29628        Sunny Room in New Condo   127608     Chris
#
#     neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0             Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 10            Manhattan  West Village  40.73530  -74.00525  Entire home/apt
# 100            Brooklyn  Clinton Hill  40.68414  -73.96351     Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0      175               3                 48  2019-11-04               0.37
# 10      65              30                 29  2020-07-25               0.22
# 100     89               3                281  2020-02-17               2.26
#
#      calculated_host_listings_count  availability_365
# 0                                 2               365
# 10                                1               197
# 100                               1               364

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340

# %% [markdown]
# ### Select row and column

# %%
df.at[ 0, 'name' ]
# Out:
# 'Skylit Midtown Castle'

# %% [markdown]
# # Basic Math
# Lets say we wanted to up the price 100x

# %%
df['new_price'] = df['price'] * 100
# df.new_price = df['price'] * 100
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price
# 0      17500
# 1       7500
# 2       6000
# 3      17500
# 4       6500

# %%
df['price'].sum()

df.price.sum()
# Out:
# 6914176

# %%
df['price'].sum() == df.price.sum()
# Out:
# True

# %% [markdown]
# Let's find the minimum booking amout by multiplying price by minimum_nights
# * note, you can also access columns by using a dot `.`

# %%
df['min_booking_amount'] = df.price * df.minimum_nights

# %% [markdown]
# # Selecting / Filtering data

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price  min_booking_amount
# 0      17500                 525
# 1       7500                  75
# 2       6000                1740
# 3      17500                2450
# 4       6500                 130

# %%
# Create our select condition.
select_condition = df['neighbourhood_group'] == 'Manhattan'

# # # Print the dataframe that meets our condition. 
# df_manhattan = df[ select_condition ]
select_condition
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 46522     True
# 46523     True
# 46524    False
# 46525     True
# 46526    False
# Name: neighbourhood_group, Length: 46527, dtype: bool

# %%
# Making a new data frame of just Manhattan
select_condition = df['neighbourhood_group'] == 'Manhattan'

df_manhattan = df[select_condition ]

df_manhattan.head()
# Out:
#      id                                     name  host_id  host_name  \
# 0  2595                    Skylit Midtown Castle     2845   Jennifer
# 4  5178         Large Furnished Room Near B'way　     8967   Shunichi
# 5  5203       Cozy Clean Guest Room - Family Apt     7490  MaryEllen
# 6  5238       Cute & Cozy Lower East Side 1 bdrm     7549        Ben
# 7  5552  Spacious river view in the West Village     8380      Maria
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan          Midtown  40.75362  -73.98377  Entire home/apt
# 4           Manhattan   Hell's Kitchen  40.76489  -73.98493     Private room
# 5           Manhattan  Upper West Side  40.80178  -73.96723     Private room
# 6           Manhattan        Chinatown  40.71344  -73.99037  Entire home/apt
# 7           Manhattan     West Village  40.73552  -74.01042  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    175               3                 48  2019-11-04               0.37
# 4     65               2                473  2020-03-15               3.44
# 5     75               2                118  2017-07-21               0.89
# 6    140               1                161  2019-07-29               1.21
# 7    160               3                 66  2019-08-10               0.49
#
#    calculated_host_listings_count  availability_365  new_price  \
# 0                               2               365      17500
# 4                               1               340       6500
# 5                               1                 0       7500
# 6                               4               274      14000
# 7                               1               178      16000
#
#    min_booking_amount
# 0                 525
# 4                 130
# 5                 150
# 6                 140
# 7                 480

# %%
# Select Brooklyn
condition_1 = df['neighbourhood_group'] == 'Brooklyn'

# Select Prices that are higher than 500
condition_2 = df['price'] > 500

# Select all data that meets both requirments
bk_high = df[condition_1 & condition_2]
bk_high
# Out:
#              id                                               name    host_id  \
# 67        19601                perfect for a family or small group      74303
# 125       38663                   Luxury Brownstone in Boerum Hill     165789
# 288       89427                               The Brooklyn Waverly     116599
# 308      103311                  2 BR w/ Terrace @ Box House Hotel     417504
# 355      141335                             Architect's Brownstone     687361
# ...         ...                                                ...        ...
# 45747  44223269  Cozy furn. duplex in the heart of BK w W/D in ...  356290430
# 46104  44449983   New 14 Bed 6 Full Bath 4500 SF Triplex Apartment  262657892
# 46148  44475802       Furnished Room in Williamsburg 3BR Apartment  306298527
# 46216  44530152                   1 bedroom apartment in Bushwick!   10932987
# 46337  44625524    Renovated Brownstone w/ Yard Near Prospect Park    2771914
#
#                  host_name neighbourhood_group       neighbourhood  latitude  \
# 67                  Maggie            Brooklyn    Brooklyn Heights  40.69723
# 125                  Sarah            Brooklyn         Boerum Hill  40.68559
# 288                   Sahr            Brooklyn        Clinton Hill  40.68613
# 308    The Box House Hotel            Brooklyn          Greenpoint  40.73778
# 355                   Orna            Brooklyn          Park Slope  40.67535
# ...                    ...                 ...                 ...       ...
# 45747                Peter            Brooklyn  Bedford-Stuyvesant  40.69390
# 46104               Philip            Brooklyn       Crown Heights  40.66492
# 46148             Daniella            Brooklyn        Williamsburg  40.71188
# 46216                 Suad            Brooklyn  Bedford-Stuyvesant  40.68685
# 46337                  Ian            Brooklyn     Windsor Terrace  40.65772
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 67     -73.99268  Entire home/apt   2000               1                 25
# 125    -73.98094  Entire home/apt    650               3                 23
# 288    -73.96536  Entire home/apt    650               5                  0
# 308    -73.95366     Private room    599               3                  9
# 355    -73.97654  Entire home/apt    685               1                 35
# ...          ...              ...    ...             ...                ...
# 45747  -73.94496     Private room   1500              30                  0
# 46104  -73.92991  Entire home/apt    660               3                  0
# 46148  -73.94042  Entire home/apt    900               1                  0
# 46216  -73.92113     Private room   1118              30                  0
# 46337  -73.97696  Entire home/apt    995               5                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 67     2016-08-04               0.21                               1
# 125    2018-12-31               0.23                               1
# 288           NaN                NaN                               3
# 308    2018-05-19               0.08                              28
# 355    2018-01-13               0.35                               1
# ...           ...                ...                             ...
# 45747         NaN                NaN                               1
# 46104         NaN                NaN                               5
# 46148         NaN                NaN                               1
# 46216         NaN                NaN                               1
# 46337         NaN                NaN                               1
#
#        availability_365  new_price  min_booking_amount
# 67                  134     200000                2000
# 125                 365      65000                1950
# 288                 364      65000                3250
# 308                 215      59900                1797
# 355                 365      68500                 685
# ...                 ...        ...                 ...
# 45747               178     150000               45000
# 46104               249      66000                1980
# 46148               365      90000                 900
# 46216               122     111800               33540
# 46337                23      99500                4975
#
# [205 rows x 18 columns]

# %% [markdown]
# ## Using 'or' statments
# * What if we want to find all listings in Midtown or DUMBO
# * The 'or' in python is the pipe thing `|`

# %%
condition_1 = df.neighbourhood == 'Midtown'

condition_2 = df.neighbourhood == 'DUMBO'

# Select all data that meets condition 1 or condition 2
df[ condition_1 | condition_2]
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 187       59855                            One bedroom Apt. in NYC     288031
# 200       61509                Quiet, clean midtown apt w. elevato      23619
# 317      110739  Central Nomad/Chelsea Loft Studio - metro dnst...     568568
# 496      225297                         Quiet sunny studio Midtown    1173599
# ...         ...                                                ...        ...
# 46451  44691898               Wyndham Midtown 45, 1 Bedroom Deluxe   71338355
# 46452  44692548    Wyndham Midtown 45, 1 Bedroom Deluxe Accessible   71338355
# 46470  44730059                         Wyndham Midtown 45, Studio   71338355
# 46480  44743937                                         443 Studio   99067861
# 46495  44758487    Large Charming Studio in Midtown East Manhattan  113107378
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 187         Leslie           Manhattan       Midtown  40.75890  -73.96991
# 200     Anna/Fonzy           Manhattan       Midtown  40.75749  -73.96897
# 317          Driss           Manhattan       Midtown  40.74503  -73.98876
# 496           Gaya           Manhattan       Midtown  40.74267  -73.98569
# ...            ...                 ...           ...       ...        ...
# 46451      Stephen           Manhattan       Midtown  40.75334  -73.97153
# 46452      Stephen           Manhattan       Midtown  40.75379  -73.97321
# 46470      Stephen           Manhattan       Midtown  40.75329  -73.97364
# 46480  Eliza Sabet           Manhattan       Midtown  40.74743  -73.98855
# 46495        Susan           Manhattan       Midtown  40.75655  -73.96501
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Entire home/apt    175               3                 48  2019-11-04
# 187    Entire home/apt    250              30                 82  2016-01-05
# 200    Entire home/apt    110             200                 92  2019-04-30
# 317    Entire home/apt    110              14                 58  2019-11-12
# 496    Entire home/apt     95               5                  5  2020-02-14
# ...                ...    ...             ...                ...         ...
# 46451  Entire home/apt    629               2                  0         NaN
# 46452  Entire home/apt    629               2                  0         NaN
# 46470  Entire home/apt    629               2                  0         NaN
# 46480     Private room     66               1                  0         NaN
# 46495  Entire home/apt     80              29                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.37                               2               365
# 187                 0.69                               1               227
# 200                 0.79                               1                 0
# 317                 0.54                               1               288
# 496                 0.05                               1                 0
# ...                  ...                             ...               ...
# 46451                NaN                               3                89
# 46452                NaN                               3                89
# 46470                NaN                               3                89
# 46480                NaN                              44               361
# 46495                NaN                               1               166
#
#        new_price  min_booking_amount
# 0          17500                 525
# 187        25000                7500
# 200        11000               22000
# 317        11000                1540
# 496         9500                 475
# ...          ...                 ...
# 46451      62900                1258
# 46452      62900                1258
# 46470      62900                1258
# 46480       6600                  66
# 46495       8000                2320
#
# [1673 rows x 18 columns]

# %% [markdown]
# # Why doesn't this work..?

# %%
# Why doesn't this work..?

condition_1 = df.neighbourhood == 'Midtown'

condition_2 = df.neighbourhood == 'DUMBO'

# Select all data that meets condition 1 or condition 2
df[ condition_1 & condition_2]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, new_price, min_booking_amount]
# Index: []

# %% [markdown]
# ## Using `.isin`. A very handy selector tool.

# %%
# List of neighborhoods we want to select
neighborhoods = ['Midtown', 'DUMBO', 'Queens']

# Create our select condition aka 'boolean mask'
condition = df.neighbourhood.isin(neighborhoods)

# Display the filtered data
df[condition]
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 187       59855                            One bedroom Apt. in NYC     288031
# 200       61509                Quiet, clean midtown apt w. elevato      23619
# 317      110739  Central Nomad/Chelsea Loft Studio - metro dnst...     568568
# 496      225297                         Quiet sunny studio Midtown    1173599
# ...         ...                                                ...        ...
# 46451  44691898               Wyndham Midtown 45, 1 Bedroom Deluxe   71338355
# 46452  44692548    Wyndham Midtown 45, 1 Bedroom Deluxe Accessible   71338355
# 46470  44730059                         Wyndham Midtown 45, Studio   71338355
# 46480  44743937                                         443 Studio   99067861
# 46495  44758487    Large Charming Studio in Midtown East Manhattan  113107378
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 187         Leslie           Manhattan       Midtown  40.75890  -73.96991
# 200     Anna/Fonzy           Manhattan       Midtown  40.75749  -73.96897
# 317          Driss           Manhattan       Midtown  40.74503  -73.98876
# 496           Gaya           Manhattan       Midtown  40.74267  -73.98569
# ...            ...                 ...           ...       ...        ...
# 46451      Stephen           Manhattan       Midtown  40.75334  -73.97153
# 46452      Stephen           Manhattan       Midtown  40.75379  -73.97321
# 46470      Stephen           Manhattan       Midtown  40.75329  -73.97364
# 46480  Eliza Sabet           Manhattan       Midtown  40.74743  -73.98855
# 46495        Susan           Manhattan       Midtown  40.75655  -73.96501
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Entire home/apt    175               3                 48  2019-11-04
# 187    Entire home/apt    250              30                 82  2016-01-05
# 200    Entire home/apt    110             200                 92  2019-04-30
# 317    Entire home/apt    110              14                 58  2019-11-12
# 496    Entire home/apt     95               5                  5  2020-02-14
# ...                ...    ...             ...                ...         ...
# 46451  Entire home/apt    629               2                  0         NaN
# 46452  Entire home/apt    629               2                  0         NaN
# 46470  Entire home/apt    629               2                  0         NaN
# 46480     Private room     66               1                  0         NaN
# 46495  Entire home/apt     80              29                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.37                               2               365
# 187                 0.69                               1               227
# 200                 0.79                               1                 0
# 317                 0.54                               1               288
# 496                 0.05                               1                 0
# ...                  ...                             ...               ...
# 46451                NaN                               3                89
# 46452                NaN                               3                89
# 46470                NaN                               3                89
# 46480                NaN                              44               361
# 46495                NaN                               1               166
#
#        new_price  min_booking_amount
# 0          17500                 525
# 187        25000                7500
# 200        11000               22000
# 317        11000                1540
# 496         9500                 475
# ...          ...                 ...
# 46451      62900                1258
# 46452      62900                1258
# 46470      62900                1258
# 46480       6600                  66
# 46495       8000                2320
#
# [1673 rows x 18 columns]

# %%
# Here is a list of ids we want to select
list_of_host_ids = [19303369, 29871437, 63953718, 32084117]


# Make our select condition 
condition = df.host_id.isin(list_of_host_ids)

# Make the selection
df[condition]
# Out:
#              id                                               name   host_id  \
# 6630    6130145                      Moma Casanova. New Additions!  29871437
# 9282    8627973     2BR2BA apartment, PRIVATE bathroom & AC inside  19303369
# 16705  16190902                              Your point in Chelsea  32084117
# 17837  17385865       Cozy PRIVATE bathroom CLEAN New Construction  19303369
# 25031  24103912  ⭐︎⭐︎PRIVATE Bathroom⭐︎⭐︎2min to subway+huge li...  19303369
# ...         ...                                                ...       ...
# 46030  44394849  Awesome Access! to station, 2min/5 line u can ...  19303369
# 46080  44434505  ★☆Sunnysid☆★ -Locals' favorite neighbor for li...  19303369
# 46209  44520855    Sunnyside -Locals' favorite neighbor for living  19303369
# 46252  44555814      Close to Manhattan! Comfortable area to stay♪  19303369
# 46295  44580140     Cozy room&house in Woodside, comfortable are!!  19303369
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 6630      Ester              Queens     Sunnyside  40.74315  -73.91733
# 9282     Hiroki              Queens      Elmhurst  40.74073  -73.87591
# 16705  Fernando           Manhattan       Chelsea  40.74183  -73.99997
# 17837    Hiroki              Queens      Elmhurst  40.73889  -73.87713
# 25031    Hiroki              Queens      Woodside  40.74267  -73.90354
# ...         ...                 ...           ...       ...        ...
# 46030    Hiroki              Queens      Woodside  40.74471  -73.89185
# 46080    Hiroki              Queens     Sunnyside  40.73860  -73.92717
# 46209    Hiroki              Queens     Sunnyside  40.73813  -73.92714
# 46252    Hiroki              Queens     Sunnyside  40.73926  -73.92557
# 46295    Hiroki              Queens      Woodside  40.74289  -73.89598
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 6630      Private room     78               3                130  2020-03-10
# 9282      Private room     40              29                  2  2020-01-02
# 16705  Entire home/apt    120               2                162  2020-06-30
# 17837     Private room     35              30                  0         NaN
# 25031     Private room     44              31                  1  2018-09-16
# ...                ...    ...             ...                ...         ...
# 46030     Private room     38              30                  0         NaN
# 46080     Private room     32              30                  0         NaN
# 46209     Private room     28              30                  0         NaN
# 46252     Private room     28              30                  0         NaN
# 46295     Private room     25              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 6630                2.03                               1               339
# 9282                0.13                              98                31
# 16705               3.60                               2               352
# 17837                NaN                              98                 0
# 25031               0.04                              98                 0
# ...                  ...                             ...               ...
# 46030                NaN                              98                52
# 46080                NaN                              98                45
# 46209                NaN                              98                45
# 46252                NaN                              98                45
# 46295                NaN                              98                31
#
#        new_price  min_booking_amount
# 6630        7800                 234
# 9282        4000                1160
# 16705      12000                 240
# 17837       3500                1050
# 25031       4400                1364
# ...          ...                 ...
# 46030       3800                1140
# 46080       3200                 960
# 46209       2800                 840
# 46252       2800                 840
# 46295       2500                 750
#
# [105 rows x 18 columns]

# %%
list_of_hoods = ['Sunnyside', 'Woodside']

select_statement = df.neighbourhood.isin(list_of_hoods)

df[select_statement]
# Out:
#              id                                               name    host_id  \
# 60        18195                 King of Queens w/ Private Bathroom      70091
# 61        18198                              Little King of Queens      70091
# 130       39593                  A room of own w/ a Manhattan view     110506
# 473      209310   Sunnyside NYC/ AC room/ city views/ near Midtown    1031148
# 614      263776                City Skyline Views from every room!    1384111
# ...         ...                                                ...        ...
# 46293  44579912   Antique style apartment/Comfortable area@Queens.  200239515
# 46294  44580012   It takes 30 minutes approximately for Manhattan.  334163301
# 46295  44580140     Cozy room&house in Woodside, comfortable are!!   19303369
# 46341  44628752  Gorgeous zen huge 2 bedroom apartment in Sunny...   31913440
# 46426  44677711               Great location in Woodside Queens NY   26055080
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 60       Justin              Queens      Woodside  40.74590  -73.90764
# 61       Justin              Queens      Woodside  40.75038  -73.90334
# 130       Myung              Queens     Sunnyside  40.74559  -73.92313
# 473       Iulia              Queens     Sunnyside  40.73826  -73.92458
# 614      Joanne              Queens     Sunnyside  40.74558  -73.92324
# ...         ...                 ...           ...       ...        ...
# 46293     Shogo              Queens      Woodside  40.74280  -73.89646
# 46294      Soya              Queens      Woodside  40.74141  -73.89582
# 46295    Hiroki              Queens      Woodside  40.74289  -73.89598
# 46341  Courtney              Queens     Sunnyside  40.73934  -73.92531
# 46426     Danny              Queens      Woodside  40.74541  -73.89826
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 60        Private room     90               7                 22  2020-05-16
# 61        Private room     75              14                 27  2020-04-30
# 130       Private room     73              30                 29  2019-12-22
# 473       Private room     50               1                281  2020-03-16
# 614       Private room     83               2                 95  2019-01-02
# ...                ...    ...             ...                ...         ...
# 46293     Private room     28              20                  0         NaN
# 46294     Private room     25              28                  0         NaN
# 46295     Private room     25              30                  0         NaN
# 46341  Entire home/apt     90               3                  0         NaN
# 46426     Private room     49               2                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 60                  0.17                               2               332
# 61                  0.21                               2                14
# 130                 0.24                               1                74
# 473                 2.74                               2               102
# 614                 0.89                               2                 0
# ...                  ...                             ...               ...
# 46293                NaN                              37                31
# 46294                NaN                              83                31
# 46295                NaN                              98                31
# 46341                NaN                               3                63
# 46426                NaN                               4               363
#
#        new_price  min_booking_amount
# 60          9000                 630
# 61          7500                1050
# 130         7300                2190
# 473         5000                  50
# 614         8300                 166
# ...          ...                 ...
# 46293       2800                 560
# 46294       2500                 700
# 46295       2500                 750
# 46341       9000                 270
# 46426       4900                  98
#
# [726 rows x 18 columns]

# %%
list_of_hoods = ['Sunnyside', 'Woodside']

select_statement = df.neighbourhood.isin(list_of_hoods)

df[~select_statement]
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# 0         Jennifer           Manhattan             Midtown  40.75362
# 1      LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 2            Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 3          Rebecca            Brooklyn         Sunset Park  40.66120
# 4         Shunichi           Manhattan      Hell's Kitchen  40.76489
# ...            ...                 ...                 ...       ...
# 46522        Brian           Manhattan            Gramercy  40.73433
# 46523        Salar           Manhattan  Washington Heights  40.85820
# 46524       Nicole            Brooklyn       East Flatbush  40.65399
# 46525     Fernando           Manhattan     Upper West Side  40.78731
# 46526       Marina            Brooklyn           Gravesend  40.59945
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.98377  Entire home/apt    175               3                 48
# 1      -73.95976  Entire home/apt     75               1                340
# 2      -73.95596     Private room     60              29                 50
# 3      -73.99423  Entire home/apt    175              14                  1
# 4      -73.98493     Private room     65               2                473
# ...          ...              ...    ...             ...                ...
# 46522  -73.98383  Entire home/apt    145               7                  0
# 46523  -73.92733  Entire home/apt     87               6                  0
# 46524  -73.93287     Private room     59               3                  0
# 46525  -73.97029  Entire home/apt     80              30                  0
# 46526  -73.98209     Private room     66               1                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2019-11-04               0.37                               2
# 1      2020-08-01               4.75                               1
# 2      2019-12-02               0.37                               1
# 3      2014-01-02               0.01                               1
# 4      2020-03-15               3.44                               1
# ...           ...                ...                             ...
# 46522         NaN                NaN                               1
# 46523         NaN                NaN                               2
# 46524         NaN                NaN                               1
# 46525         NaN                NaN                               1
# 46526         NaN                NaN                               1
#
#        availability_365  new_price  min_booking_amount
# 0                   365      17500                 525
# 1                   265       7500                  75
# 2                   365       6000                1740
# 3                   295      17500                2450
# 4                   340       6500                 130
# ...                 ...        ...                 ...
# 46522               164      14500                1015
# 46523                85       8700                 522
# 46524                90       5900                 177
# 46525               113       8000                2400
# 46526                38       6600                  66
#
# [45801 rows x 18 columns]

# %%
list_of_neighbourhoods = ['DUMBO', 'Midtown']

condition = df.neighbourhood.isin(list_of_neighbourhoods)

df[~condition]
# Out:
#              id                                               name    host_id  \
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# 5          5203                 Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                                ...        ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# 1      LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 2            Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 3          Rebecca            Brooklyn         Sunset Park  40.66120
# 4         Shunichi           Manhattan      Hell's Kitchen  40.76489
# 5        MaryEllen           Manhattan     Upper West Side  40.80178
# ...            ...                 ...                 ...       ...
# 46522        Brian           Manhattan            Gramercy  40.73433
# 46523        Salar           Manhattan  Washington Heights  40.85820
# 46524       Nicole            Brooklyn       East Flatbush  40.65399
# 46525     Fernando           Manhattan     Upper West Side  40.78731
# 46526       Marina            Brooklyn           Gravesend  40.59945
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 1      -73.95976  Entire home/apt     75               1                340
# 2      -73.95596     Private room     60              29                 50
# 3      -73.99423  Entire home/apt    175              14                  1
# 4      -73.98493     Private room     65               2                473
# 5      -73.96723     Private room     75               2                118
# ...          ...              ...    ...             ...                ...
# 46522  -73.98383  Entire home/apt    145               7                  0
# 46523  -73.92733  Entire home/apt     87               6                  0
# 46524  -73.93287     Private room     59               3                  0
# 46525  -73.97029  Entire home/apt     80              30                  0
# 46526  -73.98209     Private room     66               1                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 1      2020-08-01               4.75                               1
# 2      2019-12-02               0.37                               1
# 3      2014-01-02               0.01                               1
# 4      2020-03-15               3.44                               1
# 5      2017-07-21               0.89                               1
# ...           ...                ...                             ...
# 46522         NaN                NaN                               1
# 46523         NaN                NaN                               2
# 46524         NaN                NaN                               1
# 46525         NaN                NaN                               1
# 46526         NaN                NaN                               1
#
#        availability_365  new_price  min_booking_amount
# 1                   265       7500                  75
# 2                   365       6000                1740
# 3                   295      17500                2450
# 4                   340       6500                 130
# 5                     0       7500                 150
# ...                 ...        ...                 ...
# 46522               164      14500                1015
# 46523                85       8700                 522
# 46524                90       5900                 177
# 46525               113       8000                2400
# 46526                38       6600                  66
#
# [44854 rows x 18 columns]

# %% [markdown]
# # Assigning values to filtered columns using `np.where()`
# * np.where is a handy tool that takes in a condition statement, followed by what value to set when condition is true, and then what value to set when condition is false.
# * `np.where(condition, when_true, when_false)`

# %% [markdown]
# ### We want a new column that whenever a listing is in Williamsburg, set it equal to 1, else, 0.

# %%
c1 = df['neighbourhood'] == 'Williamsburg'

df['is_in_williamsburg'] = np.where( c1, 1, 0)

df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price  min_booking_amount  is_in_williamsburg
# 0      17500                 525                   0
# 1       7500                  75                   0
# 2       6000                1740                   0
# 3      17500                2450                   0
# 4       6500                 130                   0

# %%
# You can do it with multiple conditions as well...

# First select condition.
c1 = df['neighbourhood'] == 'Williamsburg'

# Second select condition.
c2 = df['room_type'] == 'Private room'

# Set equal to one when both conditions are true, and zero when not true.
df['private_room_in_williamsburg'] =  np.where( c1 & c2, 1, 0 )

# Sanity check to view if our assignment worked correctly.
select_statement = df['private_room_in_williamsburg'] == 1

df[  select_statement ]
# Out:
#              id                                               name    host_id  \
# 42        15385                              Very, very cozy place      60252
# 63        18764                          Cozy 2 BR in Williamsburg      72014
# 69        20611                  Cozy Bedroom in Williamsburg 3 BR      72014
# 80        24143  Williamsburg—Steps To Subway, Private Bath&Bal...      97219
# 127       39282                    “Work-from-home” from OUR home.     168525
# ...         ...                                                ...        ...
# 46248  44553435     Room in a 4 bedroom apartment in Williamsburg.   40130852
# 46308  44595136  Huge 4BR duplex in North Wburg with Outdoor Sp...   30359189
# 46355  44633289  2020 Remodeled Brand New apartment in Williams...  334163301
# 46364  44640377  HUGE BEDROOM WITH PRIVATE BATHROOM IN WILLIAMS...   64191321
# 46517  44802032                  A very large room in Williamsburg  213793805
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 42     Cristina            Brooklyn  Williamsburg  40.71185  -73.96204
# 63      Yvelisa            Brooklyn  Williamsburg  40.71154  -73.96112
# 69      Yvelisa            Brooklyn  Williamsburg  40.71156  -73.96218
# 80         Seth            Brooklyn  Williamsburg  40.71332  -73.94177
# 127         Gus            Brooklyn  Williamsburg  40.71088  -73.95055
# ...         ...                 ...           ...       ...        ...
# 46248  Catarina            Brooklyn  Williamsburg  40.70871  -73.94772
# 46308    Rachel            Brooklyn  Williamsburg  40.72076  -73.96163
# 46355      Soya            Brooklyn  Williamsburg  40.70335  -73.94224
# 46364        Gg            Brooklyn  Williamsburg  40.71307  -73.93765
# 46517      Omer            Brooklyn  Williamsburg  40.71970  -73.95632
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 42     Private room     80               7                 49  2020-02-07
# 63     Private room    145               3                 63  2019-08-04
# 69     Private room     85               3                193  2019-12-18
# 80     Private room    112               3                352  2020-03-12
# 127    Private room     50               4                219  2020-07-16
# ...             ...    ...             ...                ...         ...
# 46248  Private room     89               3                  0         NaN
# 46308  Private room    100              30                  0         NaN
# 46355  Private room     29              30                  0         NaN
# 46364  Private room     55               3                  0         NaN
# 46517  Private room     55              14                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 42                  0.39                               1               229
# 63                  0.50                               2               365
# 69                  1.52                               2               365
# 80                  2.83                               1                58
# 127                 1.79                               1                60
# ...                  ...                             ...               ...
# 46248                NaN                               2               365
# 46308                NaN                               1                89
# 46355                NaN                              83                31
# 46364                NaN                               2               324
# 46517                NaN                               1                45
#
#        new_price  min_booking_amount  is_in_williamsburg  \
# 42          8000                 560                   1
# 63         14500                 435                   1
# 69          8500                 255                   1
# 80         11200                 336                   1
# 127         5000                 200                   1
# ...          ...                 ...                 ...
# 46248       8900                 267                   1
# 46308      10000                3000                   1
# 46355       2900                 870                   1
# 46364       5500                 165                   1
# 46517       5500                 770                   1
#
#        private_room_in_williamsburg
# 42                                1
# 63                                1
# 69                                1
# 80                                1
# 127                               1
# ...                             ...
# 46248                             1
# 46308                             1
# 46355                             1
# 46364                             1
# 46517                             1
#
# [1781 rows x 20 columns]

# %% [markdown]
# # Applying a functions to a column

# %%
def half_number(input_number):
    output_number = input_number / 2
    return output_number

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price  min_booking_amount
# 0      17500                 525
# 1       7500                  75
# 2       6000                1740
# 3      17500                2450
# 4       6500                 130

# %%
df['halfed_price'] = df['price'].apply(half_number)

df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price  min_booking_amount  halfed_price
# 0      17500                 525          87.5
# 1       7500                  75          37.5
# 2       6000                1740          30.0
# 3      17500                2450          87.5
# 4       6500                 130          32.5

# %%
def my_function(x):
    if 'Furnished' in str(x):
        return 1
    else:
        return 0

df['is_furnished'] = df['name'].apply( my_function )

df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price  min_booking_amount  halfed_price  is_furnished
# 0      17500                 525          87.5             0
# 1       7500                  75          37.5             0
# 2       6000                1740          30.0             0
# 3      17500                2450          87.5             0
# 4       6500                 130          32.5             1

# %%
def cut_price(x):
    return x / 2

# df['half_price'] = df['price'] * 0.5

df['cut_price'] = df.price.apply( cut_price )
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  ...  number_of_reviews  last_review  \
# 0  Entire home/apt    175  ...                 48   2019-11-04
# 1  Entire home/apt     75  ...                340   2020-08-01
# 2     Private room     60  ...                 50   2019-12-02
# 3  Entire home/apt    175  ...                  1   2014-01-02
# 4     Private room     65  ...                473   2020-03-15
#
#   reviews_per_month  calculated_host_listings_count  availability_365  \
# 0              0.37                               2               365
# 1              4.75                               1               265
# 2              0.37                               1               365
# 3              0.01                               1               295
# 4              3.44                               1               340
#
#    new_price  min_booking_amount  halfed_price  is_furnished  cut_price
# 0      17500                 525          87.5             0       87.5
# 1       7500                  75          37.5             0       37.5
# 2       6000                1740          30.0             0       30.0
# 3      17500                2450          87.5             0       87.5
# 4       6500                 130          32.5             1       32.5
#
# [5 rows x 21 columns]

# %% [markdown]
# # Grouping

# %% [markdown]
# <img src='https://i.stack.imgur.com/sgCn1.jpg'>

# %%
df.head()
df.neighbourhood_group.value_counts()
# Out:
# Manhattan        20580
# Brooklyn         18632
# Queens            5791
# Bronx             1183
# Staten Island      341
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# Doing a groupby does nothing unless you apply a function to a column of the groupby object.

# %%
df.groupby('neighbourhood_group')

# %% [markdown]
# ## After the groupby, select a column then select the function you want to perform on said column.

# %%
gb = df.groupby('neighbourhood_group')
# gb['price'].max()

# %% [markdown]
# # You can use `.agg` to do multiple functions on said column.

# %%
gb = df.groupby('neighbourhood_group')
gb['price'].agg( ['count', 'min', 'max', 'mean', 'median', 'std', 'sum'] )
# Out:
#                      count  min    max        mean  median         std  \
# neighbourhood_group
# Bronx                 1183   16   1404   92.751479      69   95.787081
# Brooklyn             18632    0  10000  120.225258      90  180.136376
# Manhattan            20580    0  10000  191.880466     129  428.682578
# Queens                5791    0  10000   99.754965      70  207.648739
# Staten Island          341   19   1200  110.947214      79  122.676152
#
#                          sum
# neighbourhood_group
# Bronx                 109725
# Brooklyn             2240037
# Manhattan            3948900
# Queens                577681
# Staten Island          37833

# %% [markdown]
# # Double groupby

# %%
groupby_cols = ['neighbourhood_group', 'neighbourhood']
gb = df.groupby(groupby_cols)
gb['price'].mean()
type(gb['price'].mean())
# Out:
# pandas.core.series.Series

# %%
gb_means = gb['price'].mean()
gb_means
# Out:
# neighbourhood_group  neighbourhood
# Bronx                Allerton          92.813953
#                      Baychester        81.750000
#                      Belmont           62.333333
#                      Bronxdale         62.666667
#                      Castle Hill       71.666667
#                                          ...
# Staten Island        Tottenville      309.000000
#                      West Brighton     89.263158
#                      Westerleigh       92.500000
#                      Willowbrook      309.000000
#                      Woodrow          700.000000
# Name: price, Length: 222, dtype: float64

# %%
gb_means.reset_index()
# Out:
#     neighbourhood_group  neighbourhood       price
# 0                 Bronx       Allerton   92.813953
# 1                 Bronx     Baychester   81.750000
# 2                 Bronx        Belmont   62.333333
# 3                 Bronx      Bronxdale   62.666667
# 4                 Bronx    Castle Hill   71.666667
# ..                  ...            ...         ...
# 217       Staten Island    Tottenville  309.000000
# 218       Staten Island  West Brighton   89.263158
# 219       Staten Island    Westerleigh   92.500000
# 220       Staten Island    Willowbrook  309.000000
# 221       Staten Island        Woodrow  700.000000
#
# [222 rows x 3 columns]

# %% [markdown]
# # Making a DataFrame out of a groupby
# * This is somewhat nuanced, but something I find people struggle on and is very handy to know how to do.

# %%
# Do your group by
gb = df.groupby('neighbourhood_group')['price'].mean()
# # # Convert it to a DataFrame
new_df = pd.DataFrame(gb)

# # # Reset the index
new_df = new_df.reset_index()

# # # Check it out
new_df
# Out:
#   neighbourhood_group       price
# 0               Bronx   92.751479
# 1            Brooklyn  120.225258
# 2           Manhattan  191.880466
# 3              Queens   99.754965
# 4       Staten Island  110.947214

# %%
for ix , row in new_df.iterrows():
    print(ix, row['neighbourhood_group'], row['price'])
# Out:
# 0 Bronx 92.75147928994083
# 1 Brooklyn 120.22525762129669
# 2 Manhattan 191.8804664723032
# 3 Queens 99.75496460024175
# 4 Staten Island 110.94721407624634

# %% [markdown]
# # Very helpful tools
# * `df.describe()`
# * `df.info`
# * `df.shape`
# * `df['column'].value_counts()`
# * `df['column'].apply(function)`
# * `df.dropna(subset=[columns])`

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude        price  \
# count  4.652700e+04  4.652700e+04  46527.000000  46527.000000  46527.00000
# mean   2.299891e+07  8.439186e+07     40.729563    -73.950918    148.60567
# std    1.373123e+07  9.913260e+07      0.054974      0.047562    318.62788
# min    2.595000e+03  2.438000e+03     40.508680    -74.239860      0.00000
# 25%    1.062558e+07  9.194284e+06     40.689945    -73.983170     65.00000
# 50%    2.220528e+07  3.719496e+07     40.724400    -73.955380    100.00000
# 75%    3.575440e+07  1.362274e+08     40.763040    -73.934170    160.00000
# max    4.481801e+07  3.624537e+08     40.911690    -73.712990  10000.00000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    46527.000000       46527.000000       35816.000000
# mean         8.519634          22.767167           0.905802
# std         23.050570          46.603900           1.280898
# min          1.000000           0.000000           0.010000
# 25%          2.000000           1.000000           0.120000
# 50%          3.000000           4.000000           0.380000
# 75%          6.000000          21.000000           1.210000
# max       1250.000000         746.000000          46.240000
#
#        calculated_host_listings_count  availability_365       new_price  \
# count                    46527.000000      46527.000000    46527.000000
# mean                         5.890451        121.142842    14860.566983
# std                         22.731346        142.517750    31862.788022
# min                          1.000000          0.000000        0.000000
# 25%                          1.000000          0.000000     6500.000000
# 50%                          1.000000         46.000000    10000.000000
# 75%                          2.000000        252.000000    16000.000000
# max                        249.000000        365.000000  1000000.000000
#
#        min_booking_amount  halfed_price  is_furnished     cut_price
# count        4.652700e+04  46527.000000  46527.000000  46527.000000
# mean         1.372545e+03     74.302835      0.006104     74.302835
# std          1.046096e+04    159.313940      0.077890    159.313940
# min          0.000000e+00      0.000000      0.000000      0.000000
# 25%          1.400000e+02     32.500000      0.000000     32.500000
# 50%          3.200000e+02     50.000000      0.000000     50.000000
# 75%          8.500000e+02     80.000000      0.000000     80.000000
# max          1.170000e+06   5000.000000      1.000000   5000.000000

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  ...  number_of_reviews  last_review  \
# 0  Entire home/apt    175  ...                 48   2019-11-04
# 1  Entire home/apt     75  ...                340   2020-08-01
# 2     Private room     60  ...                 50   2019-12-02
# 3  Entire home/apt    175  ...                  1   2014-01-02
# 4     Private room     65  ...                473   2020-03-15
#
#   reviews_per_month  calculated_host_listings_count  availability_365  \
# 0              0.37                               2               365
# 1              4.75                               1               265
# 2              0.37                               1               365
# 3              0.01                               1               295
# 4              3.44                               1               340
#
#    new_price  min_booking_amount  halfed_price  is_furnished  cut_price
# 0      17500                 525          87.5             0       87.5
# 1       7500                  75          37.5             0       37.5
# 2       6000                1740          30.0             0       30.0
# 3      17500                2450          87.5             0       87.5
# 4       6500                 130          32.5             1       32.5
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46527 entries, 0 to 46526
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              46527 non-null  int64
#  1   name                            46509 non-null  object
#  2   host_id                         46527 non-null  int64
#  3   host_name                       46492 non-null  object
#  4   neighbourhood_group             46527 non-null  object
#  5   neighbourhood                   46527 non-null  object
#  6   latitude                        46527 non-null  float64
#  7   longitude                       46527 non-null  float64
#  8   room_type                       46527 non-null  object
#  9   price                           46527 non-null  int64
#  10  minimum_nights                  46527 non-null  int64
#  11  number_of_reviews               46527 non-null  int64
#  12  last_review                     35816 non-null  object
#  13  reviews_per_month               35816 non-null  float64
#  14  calculated_host_listings_count  46527 non-null  int64
#  15  availability_365                46527 non-null  int64
#  16  new_price                       46527 non-null  int64
#  17  min_booking_amount              46527 non-null  int64
#  18  halfed_price                    46527 non-null  float64
#  19  is_furnished                    46527 non-null  int64
#  20  cut_price                       46527 non-null  float64
# dtypes: float64(5), int64(10), object(6)
# memory usage: 7.5+ MB

# %% [markdown]
# # How to find percentages of the whole using `value_counts`

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  ...  reviews_per_month  \
# 0  Entire home/apt    175  ...               0.37
# 1  Entire home/apt     75  ...               4.75
# 2     Private room     60  ...               0.37
# 3  Entire home/apt    175  ...               0.01
# 4     Private room     65  ...               3.44
#
#    calculated_host_listings_count availability_365  new_price  \
# 0                               2              365      17500
# 1                               1              265       7500
# 2                               1              365       6000
# 3                               1              295      17500
# 4                               1              340       6500
#
#    min_booking_amount  is_in_williamsburg  private_room_in_williamsburg  \
# 0                 525                   0                             0
# 1                  75                   0                             0
# 2                1740                   0                             0
# 3                2450                   0                             0
# 4                 130                   0                             0
#
#    is_furnished  half_price  cut_price
# 0             0        87.5       87.5
# 1             0        37.5       37.5
# 2             0        30.0       30.0
# 3             0        87.5       87.5
# 4             1        32.5       32.5
#
# [5 rows x 23 columns]

# %%
df.neighbourhood_group.value_counts()
# df.groupby('neighbourhood_group')
# Out:
# Manhattan        20580
# Brooklyn         18632
# Queens            5791
# Bronx             1183
# Staten Island      341
# Name: neighbourhood_group, dtype: int64

# %%
dfp = df.neighbourhood_group.value_counts() / df.neighbourhood_group.value_counts().sum()
dfp
# Out:
# Manhattan        0.442324
# Brooklyn         0.400456
# Queens           0.124465
# Bronx            0.025426
# Staten Island    0.007329
# Name: neighbourhood_group, dtype: float64

# %%
dfp = df.neighbourhood_group.value_counts(normalize = True)

# %%
dfp = dfp.round(2)
dfp
# Out:
# Manhattan        0.44
# Brooklyn         0.40
# Queens           0.12
# Bronx            0.03
# Staten Island    0.01
# Name: neighbourhood_group, dtype: float64

# %%
dfp.to_clipboard()

# %% [markdown]
# # Joins

# %%
Image('https://i.stack.imgur.com/UI25E.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-b83edf621ab3> in <module>
# ----> 1 Image('https://i.stack.imgur.com/UI25E.jpg')
#
# NameError: name 'Image' is not defined

# %%
dfprices = pd.read_csv('data/prices.csv')
dfprices
# Out:
#   neighbourhood_group   mean_price
# 0               Bronx    92.751479
# 1            Brooklyn   120.225258
# 2           Manhattan   191.880466
# 3              Queens    99.754965
# 4       Staten Island   110.947214

# %%
dflistings = pd.read_csv('data/n_listings.csv', sep=';')
dflistings
# Out:
#   neighbourhood_group  n_listings
# 0               Bronx        1183
# 1            Brooklyn       18632
# 2           Manhattan       20580
# 3          LongIsland        4121

# %%
# Merge defaults to an inner-join
new_df = pd.merge(dfprices, dflistings, on='neighbourhood_group')
new_df
# Out:
#   neighbourhood_group  mean_price  n_listings
# 0               Bronx   92.751479        1183
# 1            Brooklyn  120.225258       18632
# 2           Manhattan  191.880466       20580

# %%
# Doing a left join keeps all values in the left table
dfjoined = pd.merge(dfprices, dflistings, on='neighbourhood_group', how='outer')
dfjoined
# Out:
#   neighbourhood_group  mean_price  n_listings
# 0               Bronx   92.751479      1183.0
# 1            Brooklyn  120.225258     18632.0
# 2           Manhattan  191.880466     20580.0
# 3              Queens   99.754965         NaN
# 4       Staten Island  110.947214         NaN
# 5          LongIsland         NaN      4121.0

# %% [markdown]
# # Exporting data
# * Almost always use `index=False` when saving your csv

# %%
# This is the name of your new file
save_as = 'my-data-file.csv'

# This is the method you use, DONT FORGET INDEX=FALSE!
dfjoined.to_csv(save_as, index=False)

# %%
# Another fun way to get your data out.
dfjoined.to_clipboard(index=False)

# %% [markdown]
# # Now open up the Exercise notebook and begin your journey into Pandas.
